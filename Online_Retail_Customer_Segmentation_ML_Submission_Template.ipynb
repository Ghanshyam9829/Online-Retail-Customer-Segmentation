# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghanshyam9829/Online-Retail-Customer-Segmentation/blob/main/Online_Retail_Customer_Segmentation_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Unsupervised
#
#
#
# ##### **Contribution**    - Ghanshyam Singh Shaktawat

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# In the project a unique data set given which is from a company who sell gift items ,Given data set is having 541909 Rows and 8 Columns , columns are explianed as below :-
#
# 1.  InvoiceNo contains unique bill number given data in the form of  object  data type
# 2.  StockCode contains a unique stock/gift code  given data in the form of  object  data type
# 3.   Description contains a brief description of gift items given data in the form of  object  data type
# 4.   Quantity contains the total number of gift items quantity given data in the form of  int data type
# 5.   InvoiceDate contains the date of purchase   given data in the form of  datetime  data type
# 6.   UnitPrice contains gift price per item given data in the form of  float  data type
# 7.   CustomerID contains customer id  given data in the form of  float  data type
# 8.  Country contains the respective country name belonging to the customer
#
#
# After Uplloading the data set in the colab we do some analysis which is explained in the below points :-
#
#
#
# *   Load the data
# *   First View of the data by using Head function
# *   Exploratory data analysis
# *   Hypothesis Testing
# *   Feature Engineering & Data Pre-processing (missing values, prepare data for
#     modeling, and handled outliers and data scaling)
# *   data modeling here we have formed clusters using Kmeans cluster and
#     silhouette analysis and finally, we have visualized all clusters using dendrograms.
#
# Above steps are used for the Online Retail Customer Segmentation unsupervised capstone project.
#
#  **Insights from the project**
# 1. WHITE HANGING HEART T-LIGHT HOLDER is most in demand.
# 2. United Kingdom is the country who is buying most number of gifts.
# 3. Saudi Arabia	bought least number of gifts.
# 4. DOTCOM POSTAGE is the gift which genrated the highest revenue
#
# 5. Invoice no 5881483 is having highest quantity which is 80995
# 6. invoice NO 581483 has a final sell of 168469 .
# 7. DOT stock code gift generated a total of $ 2,06,245 in
#   revenue .
# 8. WORLD WAR 2 GLIDERS is the most bought item ever with 53847
#   quantity.
#
# 9. Total reveanue of only UK is 8 million.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **In this project, your task is to identify major customer segments on a transnational data set which contains all the transactions occurring between 01/12/2010 and 09/12/2011 for a UK-based and registered non-store online retail.The company mainly sells unique all-occasion gifts. Many customers of the company are wholesalers.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px
import pandas as pd
from datetime import datetime
from datetime import date

import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# Import The Date Class
from datetime import datetime
import datetime as dt
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score

# %%
#for model building
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBClassifier
from xgboost import XGBRFClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import metrics

# %%
#Visualiztion libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# from lime import lime_tabular
from numpy import math
from scipy.stats import *
import math
from scipy.stats import ttest_1samp
from sklearn import  svm,datasets
from sklearn.model_selection import  GridSearchCV
import plotly.express as px
import plotly.graph_objects as go
from sklearn import preprocessing

# %%
#for model evaluation
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import log_loss
from xgboost import XGBClassifier
import pandas as pd

# %%
import sklearn

# !pip install shap==0.40.0
# import shap
import graphviz
sns.set_style('darkgrid')
# !pip3 install xgboost
# !pip install interpret

import interpret.glassbox
import shap
#---- For handling warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.7/371.7 kB 5.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for shap: filename=shap-0.40.0-cp310-cp310-linux_x86_64.whl size=515073 sha256=db8a0b5a8fc7504964b6d9881b88bd77bc62ec36fb38879e4432ba289599b22e
#   Stored in directory: /root/.cache/pip/wheels/33/28/e3/62a9dc612c58c1b8d1c16fa51e64941bbb38ac8a6decbad39c
# Successfully built shap
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 46.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 758.0/758.0 kB 43.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 68.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 65.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Copy of Online Retail.xlsx'
# Out:
# Mounted at /content/drive

# %%
dataset= pd.read_excel(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print(dataset.shape)
# Out:
# (541909, 8)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
len(dataset[dataset.duplicated()])
# Out:
# 5268

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
dataset.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Visualizing the missing values
sns.heatmap(dataset.isnull() )
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Data set is having 541909 Rows and 8 Columns , and 2 columns are having the missing values Description columns is having 1454 and customer id is having 135080 missing values.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe(include='all')
# Out:
#         InvoiceNo StockCode                         Description  \
# count    541909.0    541909                              540455
# unique    25900.0      4070                                4223
# top      573585.0    85123A  WHITE HANGING HEART T-LIGHT HOLDER
# freq       1114.0      2313                                2369
# first         NaN       NaN                                 NaN
# last          NaN       NaN                                 NaN
# mean          NaN       NaN                                 NaN
# std           NaN       NaN                                 NaN
# min           NaN       NaN                                 NaN
# 25%           NaN       NaN                                 NaN
# 50%           NaN       NaN                                 NaN
# 75%           NaN       NaN                                 NaN
# max           NaN       NaN                                 NaN
#
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Fields : Description
#
# Invoice NO : Invoice number
#
# Stock Code : Stock name code
#
# Description : Description of product
#
# Quantity : Quantity bought
#
# InvoiceDate : Invoice date
#
# UnitPrice : Price per unit
#
# Customer ID : Unique customer id
#
# Country : location

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in dataset.columns.tolist():
  print("No. of unique values in ",i,"is",dataset[i].nunique(),".")
# Out:
# No. of unique values in  InvoiceNo is 25900 .
# No. of unique values in  StockCode is 4070 .
# No. of unique values in  Description is 4223 .
# No. of unique values in  Quantity is 722 .
# No. of unique values in  InvoiceDate is 23260 .
# No. of unique values in  UnitPrice is 1630 .
# No. of unique values in  CustomerID is 4372 .
# No. of unique values in  Country is 38 .

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# created new column final sell
dataset['Final_Sell']=dataset["Quantity"]*dataset["UnitPrice"]

# %%
# data set column after adding final sell
dataset.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Final_Sell'],
#       dtype='object')

# %%
# Most Demanding iteam
baught_iteams=dataset.Description.value_counts()
baught_iteams=baught_iteams.sort_values(ascending=False).reset_index().head(10)
baught_iteams.columns = ['Item Description', 'Count']
baught_iteams
# Out:
#                      Item Description  Count
# 0  WHITE HANGING HEART T-LIGHT HOLDER   2369
# 1            REGENCY CAKESTAND 3 TIER   2200
# 2             JUMBO BAG RED RETROSPOT   2159
# 3                       PARTY BUNTING   1727
# 4             LUNCH BAG RED RETROSPOT   1638
# 5       ASSORTED COLOUR BIRD ORNAMENT   1501
# 6   SET OF 3 CAKE TINS PANTRY DESIGN    1473
# 7     PACK OF 72 RETROSPOT CAKE CASES   1385
# 8             LUNCH BAG  BLACK SKULL.   1350
# 9     NATURAL SLATE HEART CHALKBOARD    1280

# %%
# Total  Purchase Count As on country
Total_country=dataset.Country.value_counts()
Total_country=Total_country.reset_index()
Total_country.columns = ['Country Name', 'Count']
Total_country
# Out:
#             Country Name   Count
# 0         United Kingdom  495478
# 1                Germany    9495
# 2                 France    8557
# 3                   EIRE    8196
# 4                  Spain    2533
# 5            Netherlands    2371
# 6                Belgium    2069
# 7            Switzerland    2002
# 8               Portugal    1519
# 9              Australia    1259
# 10                Norway    1086
# 11                 Italy     803
# 12       Channel Islands     758
# 13               Finland     695
# 14                Cyprus     622
# 15                Sweden     462
# 16           Unspecified     446
# 17               Austria     401
# 18               Denmark     389
# 19                 Japan     358
# 20                Poland     341
# 21                Israel     297
# 22                   USA     291
# 23             Hong Kong     288
# 24             Singapore     229
# 25               Iceland     182
# 26                Canada     151
# ...

# %%
# Top  5 item purchase By country
most_iteam_purchase=dataset.groupby(["Country"])['Quantity'].sum()
most_iteam_purchase=most_iteam_purchase.sort_values(ascending=False).head(5).reset_index()
most_iteam_purchase
# Out:
#           Country  Quantity
# 0  United Kingdom   4263829
# 1     Netherlands    200128
# 2            EIRE    142637
# 3         Germany    117448
# 4          France    110480

# %%
# Top 5 country from where retail shops earns more
Top_earning=dataset.groupby(['Country'])['Final_Sell'].sum()
Top_earning=Top_earning.sort_values(ascending=False).reset_index().head()
Top_earning
# Out:
#           Country   Final_Sell
# 0  United Kingdom  8187806.364
# 1     Netherlands   284661.540
# 2            EIRE   263276.820
# 3         Germany   221698.210
# 4          France   197403.900

# %%
Most_bought_item=dataset.groupby(["Description"]).agg({'Quantity':sum,'Final_Sell':sum})
Most_bought_item=Most_bought_item.sort_values( by=['Quantity','Final_Sell'], ascending=False).head(5)

# %%
Most_bought_item
# Out:
#                                    Quantity  Final_Sell
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847    13587.93
# JUMBO BAG RED RETROSPOT               47363    92356.03
# ASSORTED COLOUR BIRD ORNAMENT         36381    58959.73
# POPCORN HOLDER                        36334    33969.46
# PACK OF 72 RETROSPOT CAKE CASES       36039    21059.72

# %%
# High revenue generated gift name
total_sell_asstockcoed=dataset.groupby(["Description"])['Final_Sell'].sum().sort_values(ascending=False).reset_index().head()
total_sell_asstockcoed
# Out:
#                           Description  Final_Sell
# 0                      DOTCOM POSTAGE   206245.48
# 1            REGENCY CAKESTAND 3 TIER   164762.19
# 2  WHITE HANGING HEART T-LIGHT HOLDER    99668.47
# 3                       PARTY BUNTING    98302.98
# 4             JUMBO BAG RED RETROSPOT    92356.03

# %%
# Top 5 high cost invoce generated
top_invice=dataset.groupby(['InvoiceNo'])['Final_Sell'].sum().sort_values(ascending=False).reset_index().head(5)
top_invice
# Out:
#   InvoiceNo  Final_Sell
# 0    581483   168469.60
# 1    541431    77183.60
# 2    574941    52940.94
# 3    576365    50653.91
# 4    556444    38970.00

# %%
# top 5 most purchase item  invoce generated

top_Quant_invice=dataset.groupby(['InvoiceNo'])['Quantity'].sum().sort_values(ascending=False).reset_index().head(5)
top_Quant_invice
# Out:
#   InvoiceNo  Quantity
# 0    581483     80995
# 1    541431     74215
# 2    556917     15049
# 3    563076     14730
# 4    574941     14149

# %%
final_sell_asstockcoed=dataset.groupby(["StockCode"])['Final_Sell'].sum().sort_values(ascending=False).reset_index().head()
final_sell_asstockcoed
# Out:
#   StockCode  Final_Sell
# 0       DOT   206245.48
# 1     22423   164762.19
# 2     47566    98302.98
# 3    85123A    97894.50
# 4    85099B    92356.03

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * Invoice no 5881483 is having highest quantity which is 80995
# * invoice NO 581483 has a final sell of 168469 .
# * DOT stock code gift generated a total of $ 2,06,245 in
#   revenue .
# * WORLD WAR 2 GLIDERS is the most bought item ever with 53847
#   quantity.
#
# * Total reveanue of only UK is 8 million.
#
# * The UK has to purchase a total of $4.2 million in gift items.
#
# * WHITE HANGING HEART T-LIGHT HOLDER is most in demand.
#
# * United Kingdom is the country who is buying most number of gifts.
#
# * Saudi Arabia	bought least number of gifts.
#
# * DOTCOM POSTAGE is the gift which genrated the highest revenue

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
fig = px.pie(baught_iteams, values='Count', names='Item Description', title='Most bought items',color_discrete_sequence=px.colors.sequential.Greens)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart visually represents the distribution of items purchased from an online retail store. It is an effective tool for displaying the proportional contribution of each category to the overall purchases. The use of a pie chart simplifies the interpretation of the variety of items bought, providing a clear and concise snapshot of the distribution and emphasizing the relative significance of each category in the online retail context.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Among the ten items depicted in the pie chart, the white hanging heart T-light holder constitutes the highest proportion at 13.9%, with a count of 2369. In contrast, the natural slate heart chalkboard represents the lowest share at 7.49%, with a count of 1280.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights enable the online store to strategically focus on popular items like the white hanging heart T-light holder, potentially increasing inventory or featuring such products prominently. Understanding the least popular item, such as the natural slate heart chalkboard, allows for targeted marketing or adjustments to optimize sales. This data-driven approach enhances product offerings, customer satisfaction, and overall business performance.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code


plt.figure(figsize=(10,5))
sns.barplot(data =final_sell_asstockcoed, x='StockCode', y='Final_Sell', palette="muted")
plt.show()

final_sell_asstockcoed
# Out:
#   StockCode  Final_Sell
# 0       DOT   206245.48
# 1     22423   164762.19
# 2     47566    98302.98
# 3    85123A    97894.50
# 4    85099B    92356.03

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot visually presents stock codes alongside their respective actual sales on an online retail store. This format is crucial for comprehending the sales performance of individual items. The use of a bar plot facilitates a quick comparison of sales across different stock codes, aiding in the identification of top-performing and underperforming items. This visualization is instrumental for informed inventory management and strategic decision-making in the online retail context.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot highlights the top 5 highest-selling stock code products and their respective revenues on an online retail store. Topping the list is stock code "Dot" with the highest revenue of $206,245.48, followed by stock code 22423 generating $164,762.19. The next three top-selling products are identified by stock codes 47566, 85123A, and 85099B.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights from the top-selling stock codes guide the online store in focusing on high-revenue products like "Dot" and optimizing inventory for popular items. Understanding customer preferences enables targeted marketing efforts and personalized promotions. By strategically managing stock based on sales data, the store can enhance customer satisfaction, maximize revenue, and make informed decisions for sustained business growth.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(30,15))
sns.barplot(data = dataset, x='Country', y='UnitPrice', palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot illustrates unit prices of products sold by an online retail store, with countries depicted on the X-axis. This visual representation is crucial for comparing product pricing across different countries. The plot provides a clear overview of the variations in unit prices, aiding the identification of pricing trends and potential market insights, which can inform pricing strategies and optimize revenue generation for the online store.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Singapore boasts the highest unit prices, exceeding 100, in contrast to other countries, none of which surpass 25. Portugal follows as the second-highest. This insight from the bar plot emphasizes significant pricing disparities across countries, offering valuable information for strategic decision-making and market analysis in the online retail store.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights allow the online store to tailor pricing strategies based on geographical trends. By recognizing Singapore's higher unit prices, the store can optimize revenue from that market. Understanding Portugal's standing aids in targeted marketing and promotions. This data-driven approach enhances profitability, customer satisfaction, and overall business performance, ensuring the online store is strategically positioned in diverse markets.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
Most_baught_item=sns.heatmap(Most_bought_item,cmap='PiYG' , annot=True , fmt=".0f",linewidths=1 )
print(Most_bought_item)
# Out:
#                                    Quantity  Final_Sell
# Description
# WORLD WAR 2 GLIDERS ASSTD DESIGNS     53847    13587.93
# JUMBO BAG RED RETROSPOT               47363    92356.03
# ASSORTED COLOUR BIRD ORNAMENT         36381    58959.73
# POPCORN HOLDER                        36334    33969.46
# PACK OF 72 RETROSPOT CAKE CASES       36039    21059.72

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The heatmap visually presents the top 5 most purchased items, detailing their respective quantities and final sales. This format is crucial for instantaneously recognizing high-performing products and their sales impact. Heatmaps provide an efficient and visually intuitive method for identifying patterns and trends, offering a comprehensive overview of product popularity and aiding strategic decision-making for inventory management and marketing strategies in the online retail context.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This heatmap reveals the top 5 most purchased items. The highest quantity, 53,847, and final sell of 13,588 are attributed to the "World War 2 Glider Assorted Designs." Following closely is the "Jumbo Bag Red Retrospot" with 47,363 units and a final sell of 92,356. Other notable entries include the "Assorted Colour Bird Ornament" (36,381 units, final sell 58,960), "Popcorn Holder" (36,334 units, final sell 33,969), and "Pack of 72 Retrospot Cake Cases" (36,039 units, final sell 21,060).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights gleaned from the heatmap guide the online store in several ways. Identifying the top-selling products allows for strategic inventory management and targeted marketing efforts. Recognizing the popularity of specific items aids in optimizing stock levels and promotional activities, enhancing customer satisfaction and maximizing revenue. This data-driven approach ensures the online store can effectively meet demand, streamline operations, and ultimately improve overall business performance.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,5))
sns.barplot(data=Top_earning, x='Country', y='Final_Sell', palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot highlights the top 5 revenue earners in various countries, showcasing their respective final sales. This visual representation is instrumental in swiftly identifying the highest-performing markets and their corresponding sales figures. Bar plots provide a clear and concise overview of revenue distribution, enabling strategic decision-making for targeted marketing efforts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The plot indicates that the United Kingdom (UK) boasts the highest sales, exceeding 8, while the remaining four countries—Netherlands, EIRE, Germany, and France—show significantly lower sales, each falling below 1. This insight underscores the UK's dominant revenue contribution, emphasizing potential market opportunities and areas for strategic focus and business development.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights are instrumental for the online store's strategic decision-making. Recognizing the UK's dominance in sales allows for tailored marketing strategies and enhanced stock management to meet demand. Identifying underperforming markets, like Netherlands, EIRE, Germany, and France, prompts targeted efforts for market expansion or optimization. This data-driven approach fosters increased revenue, customer satisfaction, and overall business success.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

plt.figure(figsize=(10,5))
sns.barplot(data = most_iteam_purchase, x='Country', y='Quantity', palette="muted")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot illustrates the highest earnings in different countries along with their corresponding quantities. This visual representation is crucial for swiftly identifying top-performing markets and the volume of products sold. Bar plots provide a clear overview of revenue distribution, aiding strategic decision-making.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The plot indicates that the United Kingdom (UK) leads in quantity with a value exceeding 4.0, while the other four countries—Netherlands, EIRE, Germany, and France—demonstrate significantly lower quantities, each falling below 0.5. This observation emphasizes the UK's substantial sales volume, underscoring potential market opportunities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights are pivotal for the online store's strategic planning. Recognizing the UK's dominance in quantity highlights the market's demand, allowing for optimized inventory management and targeted marketing. Identifying the lower quantities in other countries prompts strategic decisions for market expansion or promotional efforts. This data-driven approach ensures the online store can meet varying demands effectively, fostering increased customer satisfaction, revenue, and overall business success.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
fig = px.pie(Total_country, values='Count', names='Country Name',
             title='Country who is placing most orders',
             hover_data=['Country Name'], labels={'Country Name':'Country Name'},color_discrete_sequence=px.colors.sequential.Greens)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart displays the total order count from different countries, providing a visual breakdown of each country's contribution. This representation is crucial for swiftly grasping the distribution of orders across various regions. Pie charts offer a concise overview, facilitating the identification of major contributors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart details order counts from 18 countries. The UK leads with 495,478 orders, constituting 91.4% of the total. Germany follows at 1.75%, while RSA has the lowest count at 58 orders. This breakdown is crucial for understanding the distribution of orders.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights guide strategic decisions for the online store. Recognizing the UK's substantial order contribution prompts tailored marketing strategies and efficient inventory management. Identifying lower counts in other countries prompts targeted efforts for market expansion.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
fig = px.pie(baught_iteams, values='Count', names='Item Description', title='Most bought items',color_discrete_sequence=px.colors.sequential.Greens)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart visually represents the variety of items purchased, indicating the count for each. This format is crucial for swiftly comprehending the distribution of purchases across different products. Pie charts provide a clear and concise overview, facilitating the identification of popular items.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This representation showcases the top 10 most purchased items. The highest, at 13.9%, is the White Hanging Heart T-light Holder with 2,369 units. Following closely is the Regency Cakestand 3 Tier, constituting 12.9% with 2,200 units. The least purchased is the Natural Slate Heart Chalkboard, accounting for 7.49% with 1,280 units.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights are invaluable for the online store's strategic decisions. Recognizing the popularity of items like the White Hanging Heart T-light Holder allows for targeted marketing and optimized stock levels. Identifying less popular items, such as the Natural Slate Heart Chalkboard, guides decisions for potential promotions or adjustments. This data-driven approach enhances customer satisfaction, inventory management, and overall business success.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
fig = px.pie(top_invice, values='Final_Sell', names='InvoiceNo')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The pie chart visually displays the top 5 invoice numbers alongside their respective final sales values. This format is crucial for swiftly understanding the distribution of revenue across different transactions. Pie charts provide a clear and concise overview, facilitating the identification of high-performing invoices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The analysis reveals that the top invoice is 581483, contributing 43.4% to the total sales with a final value of 541,431. Following closely is invoice no. 541431, accounting for 19.9% and a final sale of 77,183.6. Subsequent top invoices include 574941 (13.6%, final sell: 52,940.94), 576365 (13%, final sell: 50,653.91), and 556444 (10%, final sell: 38,970). This breakdown assists in identifying major revenue contributors, facilitating strategic financial decision-making.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights are crucial for the online store's financial strategy. Recognizing the top-performing invoices, such as 581483, enables focused efforts on high-value transactions. Identifying lower contributors prompts targeted strategies for revenue optimization or customer engagement. This data-driven approach ensures effective financial decision-making, leading to increased revenue.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.title=("Sell Graph According to the Country")
sns.lineplot(x="Country", y="Final_Sell", data=Top_earning)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The line plot visually represents sales trends in the top 5 countries. This format is crucial for swiftly discerning the variations in sales across different regions over time. Line plots provide a clear and concise overview, facilitating the identification of trends. It ensures a focused and insightful approach to enhance overall operational efficiency in the online retail context.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As per the plot, the United Kingdom exhibits the highest sales quantity, surpassing 8, while the other four countries—Netherlands, EIRE, Germany, and France—show considerably lower quantities, each falling below 1. This observation highlights the significant sales volume in the UK and underscores potential areas for strategic focus or adjustments in the online retail context.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights are vital for shaping the online store's strategy. Recognizing the UK's substantial sales volume prompts tailored marketing and inventory management strategies to meet high demand. Identifying lower sales in other countries prompts targeted efforts for market expansion or promotional initiatives.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(12,5))
plt.xlabel('InvoiceNo')
plt.ylabel('Quantity')
plt.title=("top 5 InvoiceNo generated high quntity")
sns.barplot(data = top_Quant_invice, x ='InvoiceNo', y='Quantity', palette="muted")
plt.show()

plt.figure()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar plot visually highlights the top 5 invoices with the highest quantities. This format is crucial for swiftly identifying transactions with significant order volumes. Bar plots provide a clear and concise overview, facilitating the identification of high-performing invoices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph reveals that invoice no. 581483 has the highest quantity, exceeding 80,000, followed by invoice no. 541431 with a quantity surpassing 70,000. Invoices 556917, 563076, and 574941 have quantities less than 20,000, with minimal differences among them. This insight is vital for recognizing major order contributors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights are essential for the online store's strategic decisions. Recognizing invoices like 581483 with substantial quantities prompts optimized inventory management and targeted marketing. Identifying lower quantities in other invoices prompts strategic decisions for potential promotions or adjustments. This data-driven approach ensures the online store can effectively meet varying demands, fostering increased customer satisfaction, revenue.

# %% [markdown]
# #### Chart - 12 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

plt.figure(figsize=(18, 8))
dataplot = sns.heatmap(dataset.corr(), cmap="YlGnBu", annot=True)
  # displaying heatmap
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We use heat map for understanding the relation between the variables ,aboove graph will show the relation beteween all the columns which is present in the data set .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We can observe Quantity is highly corelated to final sell .

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# *   Is 5$ price for each gift product?
# *   Is 10 quantity of gift buying across UK region?
# *   Consider the final sales is 15

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis: N = 5
#
# Alternate Hypothesis : N < 5
#
# Test Type: Z test
#
# Is 5$ price for each gift product?

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import metrics
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import *
import math
from statsmodels.stats import weightstats as stests
print(dataset['UnitPrice'].mean())
dataset[['UnitPrice']].describe()
ztest ,propability_value = stests.ztest(dataset['UnitPrice'], x2=None, value=5)
print(f"P Value is : {float(propability_value)}")
if propability_value<0.05:
    print("Null hyphothesis rejected , Alternative hyphothesis accepted")
else:
    print("Null hyphothesis accepted , Alternative hyphothesis rejected")
# Out:
# 4.611113626088513
# P Value is : 0.003090095227840552
# Null hyphothesis rejected , Alternative hyphothesis accepted

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Z Test

# %%
fig=plt.figure(figsize=(5,3))
ax=fig.gca()
feature= (dataset['UnitPrice'])
sns.histplot(dataset['UnitPrice'],bins=10)
ax.axvline(feature.mean(),color='magenta', linestyle='dashed', linewidth=4)
ax.axvline(feature.median(),color='cyan', linestyle='dashed', linewidth=4)
ax.set_title('UnitPrice')
plt.show()

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# We use Z test for the normal distributed data , and when the sample size is too high and variance is know we use the  Z test , by using the Z test we can assess that population mean are different or same , A z-statistic, also known as a z-score, is a numerical representation of the outcome of a z-test.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis: N = 10
#
# Alternate Hypothesis : N < 10
#
# Test Type: Z test
#
# Is 10 quantity of gift buying across UK region?

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import metrics
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import *
import math
from statsmodels.stats import weightstats as stests
print(dataset['Quantity'].mean())
dataset[['Quantity']].describe()
ztest ,propability_value = stests.ztest(dataset['Quantity'], x2=None, value=9)
print(f"P Value is : {float(propability_value)}")
if propability_value<0.05:
    print("Null hyphothesis rejected , Alternative hyphothesis accepted")
else:
    print("Null hyphothesis accepted , Alternative hyphothesis rejected")
# Out:
# 9.55224954743324
# P Value is : 0.062300913172767466
# Null hyphothesis accepted , Alternative hyphothesis rejected

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Z-Test

# %%
fig=plt.figure(figsize=(5,3))
ax=fig.gca()
feature= (dataset['Quantity'])
sns.histplot(dataset['Quantity'],bins=10)
ax.axvline(feature.mean(),color='magenta', linestyle='dashed', linewidth=4)
ax.axvline(feature.median(),color='cyan', linestyle='dashed', linewidth=4)
ax.set_title('Quantity')
plt.show()

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# We use Z test for the normal distributed data , and when the sample size is too high and variance is know we use the  Z test , by using the Z test we can assess that population mean are different or same , A z-statistic, also known as a z-score, is a numerical representation of the outcome of a z-test.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Consider the final sales is 15
#
# Null Hypothesis: N = 15
#
# Alternate Hypothesis : N < 15
#
# Test Type: Z test
#
# Is total sell of unique product is 15?

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
print(dataset['Final_Sell'].mean())
dataset[['Final_Sell']].describe()
ztest ,propability_value = stests.ztest(dataset['Final_Sell'], x2=None, value=16)
print(f"P Value is : {float(propability_value)}")
if propability_value<0.05:
    print("Null hyphothesis rejected , Alternative hyphothesis accepted")
else:
    print("Null hyphothesis accepted , Alternative hyphothesis rejected")
# Out:
# 17.98779487699964
# P Value is : 0.00011205335704471761
# Null hyphothesis rejected , Alternative hyphothesis accepted

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Z tset

# %%
fig=plt.figure(figsize=(5,3))
ax=fig.gca()
feature= (dataset['Final_Sell'])
sns.histplot(dataset['Final_Sell'],bins=10)
ax.axvline(feature.mean(),color='magenta', linestyle='dashed', linewidth=4)
ax.axvline(feature.median(),color='cyan', linestyle='dashed', linewidth=4)
ax.set_title('Final_Sell')
plt.show()

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# We use Z test for the normal distributed data , and when the sample size is too high and variance is know we use the  Z test , by using the Z test we can assess that population mean are different or same , A z-statistic, also known as a z-score, is a numerical representation of the outcome of a z-test.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
print(dataset.isnull().sum())
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# Final_Sell          0
# dtype: int64

# %%
# Checking Null Value by plotting Heatmap
sns.heatmap(dataset.isnull(), cbar=False)
# Out:
# <Axes: >

# %%
# missing values percentage
round(100*(dataset.isnull().sum())/len(dataset), 2)
# Out:
# InvoiceNo       0.00
# StockCode       0.00
# Description     0.27
# Quantity        0.00
# InvoiceDate     0.00
# UnitPrice       0.00
# CustomerID     24.93
# Country         0.00
# Final_Sell      0.00
# dtype: float64

# %%
# droping all rows having missing values
dataset = dataset.dropna()
dataset.shape
# Out:
# (406829, 9)

# %%
# After dropping null values data set view
dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Final_Sell
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Removed the column which is  having most missing values

# %%
# total revenue
total_revenue = dataset.groupby(['CustomerID'])['Final_Sell'].sum()
total_revenue = total_revenue.reset_index()
total_revenue.head()
# Out:
#    CustomerID  Final_Sell
# 0     12346.0        0.00
# 1     12347.0     4310.00
# 2     12348.0     1797.24
# 3     12349.0     1757.55
# 4     12350.0      334.40

# %%
total_transaction = dataset.groupby('CustomerID')['InvoiceNo'].count()
total_transaction = total_transaction.reset_index()
total_transaction.columns = ['CustomerID', 'Total_transaction']
total_transaction.head()
# Out:
#    CustomerID  Total_transaction
# 0     12346.0                  2
# 1     12347.0                182
# 2     12348.0                 31
# 3     12349.0                 73
# 4     12350.0                 17

# %%
# merging total transction and total sell
# merge the two dfs
total_revenue = pd.merge(total_revenue, total_transaction, on='CustomerID', how='inner')
total_revenue.head()
# Out:
#    CustomerID  Final_Sell  Total_transaction
# 0     12346.0        0.00                  2
# 1     12347.0     4310.00                182
# 2     12348.0     1797.24                 31
# 3     12349.0     1757.55                 73
# 4     12350.0      334.40                 17

# %%
# last date of the purchase
max_date = max(dataset['InvoiceDate'])
max_date
# Out:
# Timestamp('2011-12-09 12:50:00')

# %%
dataset['day_difference'] = max_date - dataset['InvoiceDate']
dataset.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  Final_Sell  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#      day_difference
# 0 373 days 04:24:00
# 1 373 days 04:24:00
# 2 373 days 04:24:00
# 3 373 days 04:24:00
# ...

# %%
# Recency
#Recency – How recently did the customer purchase
recent_purchase = dataset.groupby('CustomerID')['day_difference'].min()
recent_purchase = recent_purchase.reset_index()
recent_purchase.head()
# Out:
#    CustomerID    day_difference
# 0     12346.0 325 days 02:33:00
# 1     12347.0   1 days 20:58:00
# 2     12348.0  74 days 23:37:00
# 3     12349.0  18 days 02:59:00
# 4     12350.0 309 days 20:49:00

# %%
# merging  total sell, day_difference and total_transaction
#Frequency – How often do they purchase
grouped_dataset = pd.merge(total_revenue, recent_purchase, on='CustomerID', how='inner')
grouped_dataset.columns = ['CustomerID', 'amount', 'frequency', 'recency']
grouped_dataset.head()
# Out:
#    CustomerID   amount  frequency           recency
# 0     12346.0     0.00          2 325 days 02:33:00
# 1     12347.0  4310.00        182   1 days 20:58:00
# 2     12348.0  1797.24         31  74 days 23:37:00
# 3     12349.0  1757.55         73  18 days 02:59:00
# 4     12350.0   334.40         17 309 days 20:49:00

# %%
# number of days only
grouped_dataset['recency'] = grouped_dataset['recency'].dt.days
grouped_dataset.head()
# Out:
#    CustomerID   amount  frequency  recency
# 0     12346.0     0.00          2      325
# 1     12347.0  4310.00        182        1
# 2     12348.0  1797.24         31       74
# 3     12349.0  1757.55         73       18
# 4     12350.0   334.40         17      309

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
#  Outlier treatment
plt.boxplot(grouped_dataset['recency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7c8c9b4a28f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7c8c9b4a3520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7c8c9b4a1e70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7c8c9b4a0160>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7c8c9b4a0370>],
#  'means': []}

# %%
# removing (statistical) outliers
Q1 = grouped_dataset.amount.quantile(0.05)
Q3 = grouped_dataset.amount.quantile(0.95)
IQR = Q3 - Q1
grouped_dataset = grouped_dataset[(grouped_dataset.amount >= Q1 - 1.5*IQR) & (grouped_dataset.amount <= Q3 + 1.5*IQR)]

# %%
# outlier treatment for recency
Q1 = grouped_dataset.recency.quantile(0.05)
Q3 = grouped_dataset.recency.quantile(0.95)
IQR = Q3 - Q1
grouped_df = grouped_dataset[(grouped_dataset.recency >= Q1 - 1.5*IQR) & (grouped_dataset.recency <= Q3 + 1.5*IQR)]

# %%
# outlier treatment for frequency
Q1 = grouped_dataset.frequency.quantile(0.05)
Q3 = grouped_dataset.frequency.quantile(0.95)
IQR = Q3 - Q1
grouped_dataset = grouped_dataset[(grouped_dataset.frequency >= Q1 - 1.5*IQR) & (grouped_dataset.frequency <= Q3 + 1.5*IQR)]

# %%
# 1. outlier treatment
sns.boxplot(grouped_dataset['recency'])
# Out:
# <Axes: >

# %%
# 2. outlier treatment
sns.boxplot(grouped_dataset['frequency'])
# Out:
# <Axes: >

# %%
# 3. outlier treatment
sns.boxplot(grouped_df['amount'])
# Out:
# <Axes: >

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# I am Winsorization which is a method to remove the affect of the outliers during the model implementation  , Winsorization is a methode in which we measure the % Px of the metrics , the dafault % of the Winsorization is 99.9% which removes the influence of outliers effect by the logging errors or bad actors.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
# Getting the categorical columns
categorical_columns=list(set(dataset.columns.to_list()).difference(set(dataset.describe().columns.to_list())))
print("Categorical Columns are :-", categorical_columns)
# Out:
# Categorical Columns are :- ['StockCode', 'InvoiceNo', 'InvoiceDate', 'Country', 'Description']

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features

dataset.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Final_Sell', 'day_difference'],
#       dtype='object')

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
dataset.drop(['CustomerID'], axis=1,inplace=True)

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# i am not using any particuler method , am just removing on column which is CustomerID

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# I am droping CustomerID because it is having so many missing values.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data
scaled_dataset=grouped_dataset[["amount","frequency","recency"]]

# %%
# create instance
scaler=StandardScaler()

# %%
# fit scaled transform
trans_scaled_dataset=scaler.fit_transform(scaled_dataset)

# %%
trans_scaled_dataset
# Out:
# array([[-0.72373821, -0.75288754,  2.30161144],
#        [ 1.73161722,  1.04246665, -0.90646561],
#        [ 0.30012791, -0.46363604, -0.18365813],
#        ...,
#        [-0.67769602, -0.70301659,  0.86589794],
#        [-0.6231313 , -0.64317145, -0.84705678],
#        [ 0.32293822, -0.07464263, -0.50050524]])

# %%
# convert into pandas data form
trans_scaled_dataset=pd.DataFrame(trans_scaled_dataset)

# %%
trans_scaled_dataset.columns=["amount","frequency","recency"]

# %%
trans_scaled_dataset
# Out:
#         amount  frequency   recency
# 0    -0.723738  -0.752888  2.301611
# 1     1.731617   1.042467 -0.906466
# 2     0.300128  -0.463636 -0.183658
# 3     0.277517  -0.044720 -0.738141
# 4    -0.533235  -0.603275  2.143188
# ...        ...        ...       ...
# 4288 -0.624669  -0.683068 -0.193560
# 4289 -0.620853  -0.673094  1.826341
# 4290 -0.677696  -0.703017  0.865898
# 4291 -0.623131  -0.643171 -0.847057
# 4292  0.322938  -0.074643 -0.500505
#
# [4293 rows x 3 columns]

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# The StandardScaler function in sklearn is based on the concept of standardization or z-score normalization. It transforms the features of a dataset by subtracting the mean (µ) and dividing by the standard deviation (σ) of each feature. This process ensures that the standardized features have a mean of 0 and a standard deviation of 1. The goal is to bring all features to a common scale, preventing any particular feature from dominating the model training due to its original scale. It is used to standardize or normalize the features of a dataset. It ensures that the variables, which might have different scales, do not disproportionately influence the machine learning model's training process. Standardization transforms the data to have a mean (µ) of 0 and a standard deviation (σ) of 1, promoting fair contributions from all features and helping to avoid potential biases in the model's predictions.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# No Dimensionality Reduction is needed

# %%
# DImensionality Reduction (If needed)

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# Answer Here.

# %%
# Handling Imbalanced Dataset (If needed)

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1 KMeans Clustering For  4 Cluster

# %%
# ML Model - 1 Implementation
kmean_clustor=KMeans(n_clusters=4, max_iter=50)
kmean_clustor
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
# Fit the Algorithm
kmean_clustor.fit(trans_scaled_dataset)
# Out:
# KMeans(max_iter=50, n_clusters=4)

# %%
kmean_clustor.labels_
# Out:
# array([2, 0, 1, ..., 2, 1, 1], dtype=int32)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
from tabulate import tabulate
# silhouette_score
clustor_ranged=[2,3,4,5,6,7,8]
for nm_clustors in clustor_ranged:
  kmean_clustor=KMeans(n_clusters=nm_clustors, max_iter=50)
  kmean_clustor.fit(trans_scaled_dataset)

  silhoutte_analysis=silhouette_score(trans_scaled_dataset,kmean_clustor.labels_)
  print("for n_clustors={0},the silhotte score is {1}".format(nm_clustors,silhoutte_analysis))
# Out:
# for n_clustors=2,the silhotte score is 0.5415858652525395
# for n_clustors=3,the silhotte score is 0.5084896296141937
# for n_clustors=4,the silhotte score is 0.4817567985759693
# for n_clustors=5,the silhotte score is 0.46627005641897035
# for n_clustors=6,the silhotte score is 0.41698971636412085
# for n_clustors=7,the silhotte score is 0.41734157386348036
# for n_clustors=8,the silhotte score is 0.40769206550574516

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# Visualizing evaluation Metric Score chart
# Sum squred distance
ssd=[ ]
clustor_ranged=[2,3,4,5,6,7,8]
for n_clustors in clustor_ranged:
  kmean_clustor=KMeans(n_clusters=n_clustors, max_iter=50)
  kmean_clustor.fit(trans_scaled_dataset)
  ssd.append(kmean_clustor.inertia_)

# %% [markdown]
# ##Elbow chart

# %%
plt.plot(ssd,'o-b')

# %% [markdown]
# ##Dendrogram

# %%
dend=linkage(trans_scaled_dataset,method='complete',metric='euclidean')
dendrogram(dend)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# In Unsupervised ML we count the opitmal number of clusters , We are using Elbow method to find optimal number of K.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# No

# %% [markdown]
# ### ML Model - 2 KMeans Clustering For 3 Cluster

# %%
kmean_clustor1=KMeans(n_clusters=3, max_iter=50)

# %%
kmean_clustor1.fit(trans_scaled_dataset)
# Out:
# KMeans(max_iter=50, n_clusters=3)

# %%
kmean_clustor1.labels_
# Out:
# array([2, 1, 0, ..., 2, 0, 0], dtype=int32)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# silhouette_score
clustor_ranged=[2,3,4,5,6,7,8]
for nm_clustors in clustor_ranged:
  kmean_clustor1=KMeans(n_clusters=nm_clustors, max_iter=50)
  kmean_clustor1.fit(trans_scaled_dataset)

  silhoutte_analysis=silhouette_score(trans_scaled_dataset,kmean_clustor1.labels_)
  print("for n_clustors={0},the silhotte score is {1}".format(nm_clustors,silhoutte_analysis))
# Out:
# for n_clustors=2,the silhotte score is 0.5415858652525395
# for n_clustors=3,the silhotte score is 0.5084896296141937
# for n_clustors=4,the silhotte score is 0.4816217519322445
# for n_clustors=5,the silhotte score is 0.46627005641897035
# for n_clustors=6,the silhotte score is 0.41742250872395564
# for n_clustors=7,the silhotte score is 0.4156123583771924
# for n_clustors=8,the silhotte score is 0.40330310211457976

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
# Sum squred distance
ssd=[ ]
clustor_ranged=[2,3,4,5,6,7,8]
for n_clustors in clustor_ranged:
  kmean_clustor1=KMeans(n_clusters=n_clustors, max_iter=50)
  kmean_clustor1.fit(trans_scaled_dataset)
  ssd.append(kmean_clustor1.inertia_)

# %% [markdown]
# ##Elbow chart

# %%
plt.plot(ssd,'o-r')

# %% [markdown]
# ##Dendrogram

# %%
dend=linkage(trans_scaled_dataset,method='complete',metric='euclidean')
dendrogram(dend)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# In Unsupervised ML we count the opitmal number of clusters , We are using Elbow method to find optimal number of K.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# NO

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### ML Model - 3 KMeans Clustering For 5 Cluster

# %%
# ML Model - 3 Implementation
kmean_clustor2=KMeans(n_clusters=5, max_iter=50)

# %%
# Fit the Algorithm
kmean_clustor2.fit(trans_scaled_dataset)
# Out:
# KMeans(max_iter=50, n_clusters=5)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# silhouette_score
clustor_ranged=[2,3,4,5,6,7,8]
for nm_clustors in clustor_ranged:
  kmean_clustor2=KMeans(n_clusters=nm_clustors, max_iter=50)
  kmean_clustor2.fit(trans_scaled_dataset)

  silhoutte_analysis=silhouette_score(trans_scaled_dataset,kmean_clustor2.labels_)
  print("for n_clustors={0},the silhotte score is {1}".format(nm_clustors,silhoutte_analysis))
# Out:
# for n_clustors=2,the silhotte score is 0.5415858652525395
# for n_clustors=3,the silhotte score is 0.5084896296141937
# for n_clustors=4,the silhotte score is 0.47782241003860476
# for n_clustors=5,the silhotte score is 0.4661039652972969
# for n_clustors=6,the silhotte score is 0.41716581583425943
# for n_clustors=7,the silhotte score is 0.41768907282021733
# for n_clustors=8,the silhotte score is 0.39617984707905424

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
# Sum squred distance
ssd=[ ]
clustor_ranged=[2,3,4,5,6,7,8]
for n_clustors in clustor_ranged:
  kmean_clustor2=KMeans(n_clusters=n_clustors, max_iter=50)
  kmean_clustor2.fit(trans_scaled_dataset)
  ssd.append(kmean_clustor2.inertia_)

# %% [markdown]
# ##Elbow chart

# %%
plt.plot(ssd,'o-g')

# %% [markdown]
# ##Dendrogram

# %%
dend=linkage(trans_scaled_dataset,method='complete',metric='euclidean')
dendrogram(dend)
plt.show()

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# In Unsupervised ML we count the opitmal number of clusters , We are using Elbow method to find optimal number of K.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# No

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# I am using elbow chart which is a  step for unsupervised algo for finding the optimal number of clusters ,  Elbow method is one of the most popular method for k calculation, in this method we find the value of k via graphical representation , elbow graph shows WCSS values on the y-axis corresponding to the different values of K on the x-axis. WCSS is the sum of the squared distance between each point and the centroid in a cluster.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# ###KMeans Clustering For 3 Cluster

# %%
# Implementation
kmean_clustor=KMeans(n_clusters=3, max_iter=50)
kmean_clustor
# Out:
# KMeans(max_iter=50, n_clusters=3)

# %%
# Fit the Algorithm
kmean_clustor.fit(trans_scaled_dataset)
# Out:
# KMeans(max_iter=50, n_clusters=3)

# %%
kmean_clustor.labels_
# Out:
# array([2, 1, 0, ..., 2, 0, 0], dtype=int32)

# %%
# Data set
grouped_dataset['clustor_id']=kmean_clustor.labels_
grouped_dataset
# Out:
#       CustomerID   amount  frequency  recency  clustor_id
# 0        12346.0     0.00          2      325           2
# 1        12347.0  4310.00        182        1           1
# 2        12348.0  1797.24         31       74           0
# 3        12349.0  1757.55         73       18           0
# 4        12350.0   334.40         17      309           2
# ...          ...      ...        ...      ...         ...
# 4366     18278.0   173.90          9       73           0
# 4367     18280.0   180.60         10      277           2
# 4368     18281.0    80.82          7      180           2
# 4369     18282.0   176.60         13        7           0
# 4371     18287.0  1837.28         70       42           0
#
# [4293 rows x 5 columns]

# %%
sns.histplot(x="clustor_id",y="amount",data=grouped_dataset)
# Out:
# <Axes: xlabel='clustor_id', ylabel='amount'>

# %%
sns.violinplot(x="clustor_id",y="frequency",data=grouped_dataset)
# Out:
# <Axes: xlabel='clustor_id', ylabel='frequency'>

# %%
sns.boxplot(x="clustor_id",y="recency",data=grouped_dataset)
# Out:
# <Axes: xlabel='clustor_id', ylabel='recency'>

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. **Product Strategy:** The analysis of the pie chart and top purchased items guides the online store in refining its product strategy. Recognizing the popularity of items like the "White Hanging Heart T-light Holder" allows for strategic inventory management and targeted marketing. The identification of less popular items, such as the "Natural Slate Heart Chalkboard," informs decisions for potential promotions or adjustments, ensuring a product lineup that resonates with customer preferences.
#
# 2. **Revenue Optimization:** Insights from revenue-related charts, including the bar plot of top revenue earners and the pie chart of invoice numbers, provide crucial information for revenue optimization. Recognizing high-earning products and top-performing invoices allows for strategic financial decision-making. Focused efforts on high-value transactions, like invoice no. 581483, contribute to revenue maximization and effective financial management.
#
# 3. **Geographical Targeting:** The bar plot showcasing unit prices across different countries aids in geographical targeting. Understanding pricing variations, especially the highest unit prices in Singapore, allows for tailored pricing strategies. This data-driven approach ensures optimal revenue generation in diverse markets, emphasizing the importance of geographical insights in strategic decision-making.
#
# 4. **Customer Segmentation:** The line plot illustrating sales trends in different countries over time and the bar plot highlighting quantities in various countries contribute to customer segmentation. Recognizing the UK's substantial sales volume prompts tailored marketing and inventory management strategies, considering its unique position. Identifying lower sales in other countries prompts targeted efforts for market expansion or adjustments, emphasizing the significance of customer segmentation for tailored strategies.
#
# 5. **Operational Efficiency:** The heatmap depicting quantities and final sales of top items contributes to operational efficiency. Recognizing the popularity of specific items allows for strategic inventory management and targeted marketing efforts, streamlining operations. This data-driven approach ensures the online store can effectively meet demand, enhancing operational efficiency and overall business performance.
#
# In conclusion, the comprehensive analysis of diverse charts provides a multifaceted understanding of the online retail landscape. These insights empower the online store to refine its product offerings, optimize revenue streams, target specific geographical markets, tailor marketing strategies, and enhance operational efficiency, fostering sustained growth and customer satisfaction in the dynamic realm of online retail.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
